# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

#CATEGORIES=["Yes","No"]

def prepare(filepath):
    IMG_SIZE=180
    img_array=cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
    img_array=img_array/255.0
    new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    plt.imshow(new_array,cmap="gray")
    plt.show()
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)
    
model=tf.keras.models.load_model("Covid.model")

# %%
prediction=model.predict([prepare('_0_1465610.jpeg')])
print(prediction)
if prediction>.5:
    print("No")
else:
    print("Yes")
# Out:
# [[0.15224522]]
# Yes

# %% [markdown]
# ## cant detect

# %%
prediction=model.predict([prepare('2.jpeg')])
print(prediction)
if prediction>.5:
    print("No")
else:
    print("Yes")##error##
# Out:
# [[0.96272147]]
# No

# %%
prediction=model.predict([prepare('0.jpeg')])
print(prediction)
if prediction>.5:
    print("No")
else:
    print("Yes")
# Out:
# [[0.9908977]]
# No

# %%
prediction=model.predict([prepare('12.jpeg')])
print(prediction)

if prediction>.5:
    print("No")
else:
    print("Yes")
# Out:
# [[0.99952257]]
# No

# %%
#Jordan lungs
prediction=model.predict([prepare('Jordan lungs.jpg')])
print(prediction)

if prediction>.5:
    print("No")
else:
    print("Yes")  ##can not
# Out:
# [[0.9467329]]
# No
